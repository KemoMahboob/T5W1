# %% [markdown]
# ## Objective
# * The objective of this exercise is to explore and visualize the Traffic Index dataset to gain insights and understand the patterns in the data.

# %% [markdown]
# ##Dataset Description

# %% [markdown]
# | Column Name | Description | Data Type |
# | :---------------- | :------: | ----: |
# |   City  |   Name of the city	   | Object |
# | Datetime           |   Date and time of the data entry	   | Object |
# |  TrafficIndexLive    |  Real-time traffic index	   | Int |
# |  Jamscount |  Number of traffic jams	   | Int |
# |   JamsDelay  |   Total delay caused by traffic jams (in minutes)	   | Float |
# |JamsLength           |   Total length of traffic jams (in kilometers)	   | Float |
# |  TrafficIndexWeekAgo    |  Traffic index one week ago	   | Int |
# |  TravelTimeHistoric |  Historical average travel time (in minutes)	   | Float |
# |   TravelTimeLive  |   Real-time travel time (in minutes)	   | Float |

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('Task (2) Dataset.csv')

# %%
df.head()
# Out:
#        City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 0  Abudhabi  2023-07-07 08:01:30                 6          4       15.6
# 1  Abudhabi  2023-07-07 09:01:30                 7          7       20.5
# 2  Abudhabi  2023-07-07 10:46:30                 7          8       25.0
# 3  Abudhabi  2023-07-07 11:16:30                 8         11       30.6
# 4  Abudhabi  2023-07-07 12:01:30                 8         20       62.1
#
#    JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 0         0.7                   13           59.611918       54.803617
# 1         1.7                    8           60.221387       56.118629
# 2         2.8                    6           59.161978       55.518834
# 3         5.5                    6           59.738138       56.413917
# 4         6.5                    5           58.958314       56.059246

# %%
df.tail()
# Out:
#          City             Datetime  TrafficIndexLive  JamsCount  JamsDelay  \
# 66634  Riyadh  2023-12-15 03:01:30                 8         33      127.8
# 66635  Riyadh  2023-12-15 04:31:30                 6         27       87.0
# 66636  Riyadh  2023-12-15 05:01:30                 3         17       49.8
# 66637  Riyadh  2023-12-15 06:01:30                 0         16       61.3
# 66638  Riyadh  2023-12-15 07:01:30                 0         15       39.5
#
#        JamsLength  TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# 66634        20.4                    8           63.926569       63.245473
# 66635        13.8                    5           59.182641       60.012955
# 66636         6.7                    1           57.746816       57.561438
# 66637         4.3                    0           56.535277       55.463218
# 66638         5.2                    0           56.126417       54.886055

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
correlation_matrix
# Out:
#                      TrafficIndexLive  JamsCount  JamsDelay  JamsLength  \
# TrafficIndexLive             1.000000   0.876216   0.861349    0.866799
# JamsCount                    0.876216   1.000000   0.982459    0.952762
# JamsDelay                    0.861349   0.982459   1.000000    0.962679
# JamsLength                   0.866799   0.952762   0.962679    1.000000
# TrafficIndexWeekAgo          0.903282   0.806545   0.775028    0.787548
# TravelTimeHistoric           0.331072   0.305166   0.303733    0.306312
# TravelTimeLive               0.642326   0.566874   0.571188    0.569065
#
#                      TrafficIndexWeekAgo  TravelTimeHistoric  TravelTimeLive
# TrafficIndexLive                0.903282            0.331072        0.642326
# JamsCount                       0.806545            0.305166        0.566874
# JamsDelay                       0.775028            0.303733        0.571188
# JamsLength                      0.787548            0.306312        0.569065
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Traffic_Index, Date).

# %%
sns.displot(data= df, x='TrafficIndexLive', height=6, aspect=2)
plt.title(' Traffic Index Live')
plt.xlabel(' TrafficIndexLive')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Traffic_Index vs. Weather_Condition).

# %%
sns.scatterplot(data= df, x='TrafficIndexLive', y='City')
plt.title('Relationship Between TrafficIndexLive and city')
plt.xlabel('TrafficIndexLive')
plt.ylabel('City')
plt.show()

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<Axes: title={'center': 'TrafficIndexLive'}>,
#         <Axes: title={'center': 'JamsCount'}>,
#         <Axes: title={'center': 'JamsDelay'}>],
#        [<Axes: title={'center': 'JamsLength'}>,
#         <Axes: title={'center': 'TrafficIndexWeekAgo'}>,
#         <Axes: title={'center': 'TravelTimeHistoric'}>],
#        [<Axes: title={'center': 'TravelTimeLive'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df.boxplot(figsize=(12, 6))
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.scatterplot(data=df, y='City', x='TravelTimeLive', palette='tab15')
# Out:
# <ipython-input-13-ba5e99562b20>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, y='City', x='TravelTimeLive', palette='tab15')
# <Axes: xlabel='TravelTimeLive', ylabel='City'>

# %%
sns.scatterplot(data=df, y='City', x='TravelTimeHistoric', palette='tab10')
# Out:
# <ipython-input-15-4cb65525edab>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df, y='City', x='TravelTimeHistoric', palette='tab10')
# <Axes: xlabel='TravelTimeHistoric', ylabel='City'>

# %%
city_travel_time = df.groupby('City')['TravelTimeLive'].sum()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(city_travel_time, labels=city_travel_time.index, autopct='%1.1f%%', startangle=140)
plt.title('Travel Time Live Distribution by City')
plt.show()

# %%
city_travel_time = df.groupby('City')['TravelTimeHistoric'].sum()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(city_travel_time, labels=city_travel_time.index, autopct='%1.1f%%', startangle=140)
plt.title('Travel Time Live Distribution by City')
plt.show()

# %%
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Insights and Conclusions

# %% [markdown]
#  Traffic Index Live and city traffic number from Cairo big than other City Then Riyadh in second
#
# Travel Time Historic and city traffic number from Cairo big than other City Then Riyadh in second
#
# lower city of both is Abudhabi

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
